# %%
# Import packages 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read the file
fileName = "LA_AQS_2023.csv" #note on path
pd.read_csv(fileName)
# Out:
#        State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 0               6           37         1103           68103    1  34.06659
# 1               6           37         1103           42602    3  34.06659
# 2               6           37         1103           62201    1  34.06659
# 3               6           37         1103           62101    1  34.06659
# 4               6           37         1103           42603    1  34.06659
# ...           ...          ...          ...             ...  ...       ...
# 22155           6           37         1103           63301    1  34.06659
# 22156           6           37         1103           61104    1  34.06659
# 22157           6           37         1103           61103    1  34.06659
# 22158           6           37         1103           62201    1  34.06659
# 22159           6           37         1103           62101    1  34.06659
#
# ...

# %%
df = pd.read_csv(fileName) #Read it in and store it in a variable!

# %%
df.head() # describe how the file looks
# We want a specific parameter Name and Duration Description
# Arithmetic Mean is what we love

#GOTO Filtering
# Out:
#    State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 0           6           37         1103           68103    1  34.06659
# 1           6           37         1103           42602    3  34.06659
# 2           6           37         1103           62201    1  34.06659
# 3           6           37         1103           62101    1  34.06659
# 4           6           37         1103           42603    1  34.06659
#
#    Longitude  Datum            Parameter Name Duration Description  ... AQI  \
# 0 -118.22688  WGS84   Ambient Min Temperature              24 HOUR  ...   .
# 1 -118.22688  WGS84    Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 2 -118.22688  WGS84         Relative Humidity               1 HOUR  ...   .
# 3 -118.22688  WGS84       Outdoor Temperature               1 HOUR  ...   .
# 4 -118.22688  WGS84  Oxides of nitrogen (NOx)               1 HOUR  ...   .
#
#   Daily Criteria Indicator  Tribe Name  State Name  County Name    City Name  \
# ...

# %%
df['Parameter Name']
# Out:
# 0           Ambient Min Temperature
# 1            Nitrogen dioxide (NO2)
# 2                 Relative Humidity
# 3               Outdoor Temperature
# 4          Oxides of nitrogen (NOx)
#                     ...
# 22155               Solar radiation
# 22156    Wind Direction - Resultant
# 22157        Wind Speed - Resultant
# 22158             Relative Humidity
# 22159           Outdoor Temperature
# Name: Parameter Name, Length: 22160, dtype: str

# %%
df_NO2 = df[(df['Parameter Name']=='Nitrogen dioxide (NO2)') & (df['Duration Description']=='1 HOUR')]
df_NO2.head()

#GOTO Plotting
# Out:
#     State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 1            6           37         1103           42602    3  34.06659
# 19           6           37         1103           42602    1  34.06659
# 29           6           37         1103           42602    1  34.06659
# 41           6           37         1103           42602    3  34.06659
# 44           6           37         1103           42602    3  34.06659
#
#     Longitude  Datum          Parameter Name Duration Description  ... AQI  \
# 1  -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 19 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  17
# 29 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  17
# 41 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 44 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  20
#
#    Daily Criteria Indicator  Tribe Name  State Name  County Name    City Name  \
# ...

# %%
df_NO2.columns
# Out:
# Index(['State Code', 'County Code', 'Site Number', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name',
#        'Duration Description', 'Pollutant Standard', 'Date (Local)', 'Year',
#        'Day In Year (Local)', 'Units of Measure', 'Exceptional Data Type',
#        'Nonreg Observation Count', 'Observation Count', 'Observation Percent',
#        'Nonreg Arithmetic Mean', 'Arithmetic Mean',
#        'Nonreg First Maximum Value', 'First Maximum Value',
#        'First Maximum Hour', 'AQI', 'Daily Criteria Indicator', 'Tribe Name',
#        'State Name', 'County Name', 'City Name', 'Local Site Name', 'Address',
#        'MSA or CBSA Name', 'Data Source'],
#       dtype='str')

# %%
ax1 = df_NO2.plot.scatter(x='Date (Local)',y='Arithmetic Mean') # Terrible x axis.

# %%
#GOTO matplotLib
df_NO2["Date (Local)"]
# Out:
# 1        2023-01-01
# 19       2023-01-01
# 29       2023-01-01
# 41       2023-01-01
# 44       2023-01-02
#             ...
# 21264    2023-09-29
# 21297    2023-09-30
# 21298    2023-09-30
# 21307    2023-09-30
# 21308    2023-09-30
# Name: Date (Local), Length: 1092, dtype: str

# %%
df_NO2["Date (Local)"] = pd.to_datetime(df_NO2["Date (Local)"])

# %%
df_NO2["Date (Local)"]
# Out:
# 1       2023-01-01
# 19      2023-01-01
# 29      2023-01-01
# 41      2023-01-01
# 44      2023-01-02
#            ...
# 21264   2023-09-29
# 21297   2023-09-30
# 21298   2023-09-30
# 21307   2023-09-30
# 21308   2023-09-30
# Name: Date (Local), Length: 1092, dtype: datetime64[us]

# %%
date = df_NO2["Date (Local)"]
value = df_NO2["Arithmetic Mean"]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(date, value)

# To Homework
