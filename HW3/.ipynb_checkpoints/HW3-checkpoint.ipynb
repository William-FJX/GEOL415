# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('LA_AQS_2023.csv')

# %%
df_O3 = df[(df['Parameter Name']=='Ozone') & (df['Duration Description']=='1 HOUR')]

# %%
df_O3["Date (Local)"] = pd.to_datetime(df_O3["Date (Local)"])

# %%
date = df_O3["Date (Local)"]
value = df_O3["Arithmetic Mean"]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(date, value)

# %%
sb.set_theme()
sb.scatterplot(
  data=df_O3,
  x=date,
  y=value
)
plt.xticks(rotation=45)
plt.show()

# %%
df_O3_35ppbv = df_O3 = df[(df['Parameter Name']=='Ozone') & (df['Duration Description']=='1 HOUR') & (df['Arithmetic Mean'] >= 0.035)]

# %%
df_O3_max_value = df_O3['Arithmetic Mean'].max()
df_O3_max = df[df['Arithmetic Mean'] == 0.04575]
print(df_O3_max['Date (Local)'])
# Out:
# 12292    2023-05-14
# Name: Date (Local), dtype: str
